# %%
from datetime import datetime
import logging
import traceback
import os
import sys 
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
print(os.getcwd())

# %%
spark = SparkSession.builder.appName('fake_gl_explore').getOrCreate()

# %%
df = spark.read.option('header',True).option('delimiter',',').csv('/Volumes/fake_general_ledger/default/calendar/Calendar.csv')

# %%
df = spark.read.option('header',True).option('delimiter',',').csv('/Volumes/fake_general_ledger/default/chart_of_accounts')
display(df)

# %%
display(df)

# %%
df = spark.read.option('header',True).option('delimiter',',').csv('/Volumes/fake_general_ledger/default/statement_of_cash_flow')
display(df)

# %%
df = spark.read.option('header',True).option('delimiter',',').csv('/Volumes/fake_general_ledger/default/gl_raw')
display(df)

# %%
df = spark.read.option('header',True).option('delimiter',',').csv('/Volumes/fake_general_ledger/default/statement_of_changes_in_equity')
display(df)

# %%
df = spark.read.option('header',True).option('delimiter',',').csv('/Volumes/fake_general_ledger/default/territory')
display(df)
