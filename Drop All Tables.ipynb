# %%
# %sql
DROP TABLE fake_general_ledger.default.bronze_calendar;
DROP TABLE fake_general_ledger.default.bronze_chart_of_accounts;
DROP TABLE fake_general_ledger.default.bronze_general_ledger;
DROP TABLE fake_general_ledger.default.bronze_ingestion_control;
DROP TABLE fake_general_ledger.default.bronze_ingestion_observability;
DROP TABLE fake_general_ledger.default.bronze_ingestion_schema_drift;
DROP TABLE fake_general_ledger.default.bronze_statement_of_cash_flow;
DROP TABLE fake_general_ledger.default.bronze_statement_of_changes_in_equity;
DROP TABLE fake_general_ledger.default.bronze_territory;
DROP TABLE fake_general_ledger.default.dim_calendar_mt;
DROP TABLE fake_general_ledger.default.dim_calendar_vw;
DROP TABLE fake_general_ledger.default.dim_gl_account_mt;
DROP TABLE fake_general_ledger.default.dim_gl_account_vw;
DROP TABLE fake_general_ledger.default.dim_territory_mt;
DROP TABLE fake_general_ledger.default.dim_territory_vw;
DROP TABLE fake_general_ledger.default.fact_general_ledger_mt;
DROP TABLE fake_general_ledger.default.fact_general_ledger_vw;
DROP TABLE fake_general_ledger.default.monthly_actuals_vw;
DROP TABLE fake_general_ledger.default.silver_chart_of_accounts;
DROP TABLE fake_general_ledger.default.silver_general_ledger;
DROP TABLE fake_general_ledger.default.silver_level_calendar;
DROP TABLE fake_general_ledger.default.silver_statement_of_cash_flow;
DROP TABLE fake_general_ledger.default.silver_statement_of_changes_in_equity;
DROP TABLE fake_general_ledger.default.silver_territory;

# %%
# %sql
